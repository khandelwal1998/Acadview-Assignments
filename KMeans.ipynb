# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/khandelwal1998/Acadview-Assignments/blob/master/KMeans.ipynb)

# %% [markdown]
# ## Minst dataset

# %%
import pandas as pd
from sklearn.datasets import load_digits
import numpy as np
from scipy.stats import mode
import matplotlib.pyplot as plt

# %%
df=load_digits()

# %%
x=df.data
y=df.target

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=10)

# %%
pred=kmeans.fit_predict(x)

# %%
label=np.zeros_like(pred)

# %%
 label.shape
# Out:
# (1797,)

# %%
for i in range(10): 
  check = (pred == i)
  label[check]=mode(y[check])[0]

# %%
label
# Out:
# array([0, 8, 8, ..., 8, 9, 9], dtype=int32)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(accuracy_score(pred,label))
print(classification_report(y,label))
# Out:
# 0.0
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99       178
#           1       0.62      0.30      0.41       182
#           2       0.85      0.84      0.84       177
#           3       0.87      0.85      0.86       183
#           4       0.98      0.91      0.94       181
#           5       0.89      0.75      0.81       182
#           6       0.97      0.98      0.98       181
#           7       0.86      0.98      0.92       179
#           8       0.45      0.59      0.51       174
#           9       0.57      0.77      0.65       180
#
# avg / total       0.81      0.79      0.79      1797

# %% [markdown]
# ## Image

# %%
from sklearn.datasets import load_sample_image

# %%
img=load_sample_image('china.jpg')
pic=plt.axes(xticks=[],yticks=[])
pic.imshow(img)

# %%
img.shape
# Out:
# (427, 640, 3)

# %%
img=img.reshape(427*640,3)

# %%
col=KMeans(n_clusters=7)

# %%
col.fit(img)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# new image

# %%
new_img=img.reshape(427,640,3)
