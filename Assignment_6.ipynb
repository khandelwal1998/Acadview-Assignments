# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.countplot(df['RainToday'])

# %%
sns.countplot(df['RainTomorrow'])

# %%
df.plot.scatter(x='Evaporation',y='Sunshine',c='Rainfall',cmap='coolwarm')

# %%
sns.countplot(df['WindGustDir'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df.WindDir9am.value_counts().plot(kind = 'barh')
plt.title("Wind Direction 9 am")
# Out:
# Text(0.5,1,'Wind Direction 9 am')

# %%
df.WindDir3pm.value_counts().plot(kind = 'barh')
plt.title("Wind Direction 3 pm")
# Out:
# Text(0.5,1,'Wind Direction 3 pm')

# %%
sns.distplot(df['Rainfall'].dropna())
# Out:
# c:\users\karan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(x='Cloud9am', data=df)

# %%
sns.countplot(x='Cloud3pm', data=df)

# %%
sns.jointplot(x='Sunshine', y='Evaporation', data=df)
# Out:
# c:\users\karan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(x='Cloud9am', y='Rainfall', data=df)

# %%
sns.jointplot(x=df['Sunshine'], y=df['WindGustSpeed'])
# Out:
# c:\users\karan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.scatter(x=df['WindGustSpeed'], y=df['Rainfall'])
